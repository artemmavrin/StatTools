# %% [markdown]
# # Polynomial Smoothing/Regression
#
# We will show how to use the `PolynomialSmoother` class in the StatTools `smoothing` module to fit a polynomial curve through a 2D scatterplot.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks", palette="muted", color_codes=True)

from stattools.smoothing import PolynomialSmoother
from stattools.visualization import func_plot

# %%
# Set NumPy random number generator seed for replicability
np.random.seed(100)

# %% [markdown]
# ## Create Some Artificial Data

# %%
n = 100

# Actual model coefficients
a = 5
b = -3
c = 1
poly = np.poly1d((c, b, a))

x = np.random.uniform(0, 10, n)
y = a + b * x + c * (x ** 2) + np.random.normal(0, 20, n)

# Scatter plot of the raw data
plt.figure()
plt.scatter(x, y, c="b", alpha=0.7, edgecolor="k")

# Plot of the true curve
func_plot(poly, num=100, c="k")

plt.title("True Curve: $y = 5 - 3 x + x^2$")
plt.show()
plt.close()

# %% [markdown]
# ## Linear Model

# %%
# %time
model = PolynomialSmoother(deg=1).fit(x, y)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 9.3 µs

# %%
plt.figure()

# Scatter plot of the observations
plt.scatter(x, y, c="b", alpha=0.7, edgecolor="k")

# Plot of the true curve
func_plot(poly, num=100, c="k", label="True Curve")

# Plot the regression line
model.fit_plot(lw=3, c="r", label="Prediction")

plt.legend(loc="best", frameon=True, shadow=True)
plt.title(f"{model.poly_str()}")
plt.show()
plt.close()

# %% [markdown]
# ## Quadratic Model

# %%
# %time
model = PolynomialSmoother(deg=2).fit(x, y)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.72 µs

# %%
plt.figure()

# Scatter plot of the observations
plt.scatter(x, y, c="b", alpha=0.7, edgecolor="k")

# Plot of the true curve
func_plot(poly, num=100, c="k", label="True Curve")

# Plot the regression curve
model.fit_plot(lw=3, c="r", label="Prediction")

plt.legend(loc="best", frameon=True, shadow=True)
plt.title(f"{model.poly_str()}")
plt.show()
plt.close()

# %% [markdown]
# ## Cubic Model

# %%
# %time
model = PolynomialSmoother(deg=3).fit(x, y)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.2 µs

# %%
plt.figure()

# Scatter plot of the observations
plt.scatter(x, y, c="b", alpha=0.7, edgecolor="k")

# Plot of the true curve
func_plot(poly, num=100, c="k", label="True Curve")

# Plot the regression curve
model.fit_plot(lw=3, c="r", label="Prediction")

plt.legend(loc="best", frameon=True, shadow=True)
plt.title(f"{model.poly_str()}")
plt.show()
plt.close()

# %% [markdown]
# ## Quartic Model

# %%
# %time
model = PolynomialSmoother(deg=4).fit(x, y)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs

# %%
plt.figure()

# Scatter plot of the observations
plt.scatter(x, y, c="b", alpha=0.7, edgecolor="k")

# Plot of the true curve
func_plot(poly, num=100, c="k", label="True Curve")

# Plot the regression curve
model.fit_plot(lw=3, c="r", label="Prediction")

plt.legend(loc="best", frameon=True, shadow=True)
plt.title(f"{model.poly_str()}")
plt.show()
plt.close()

# %% [markdown]
# ## Quintic Model

# %%
# %time
model = PolynomialSmoother(deg=5).fit(x, y)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 9.06 µs

# %%
plt.figure()

# Scatter plot of the observations
plt.scatter(x, y, c="b", alpha=0.7, edgecolor="k")

# Plot of the true curve
func_plot(poly, num=100, c="k", label="True Curve")

# Plot the regression curve
model.fit_plot(lw=3, c="r", label="Prediction")

plt.legend(loc="best", frameon=True, shadow=True)
plt.title(f"{model.poly_str(precision=2)}")
plt.show()
plt.close()

# %% [markdown]
# ## Sextic Model

# %%
# %time
model = PolynomialSmoother(deg=6).fit(x, y)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 9.06 µs

# %%
plt.figure()

# Scatter plot of the observations
plt.scatter(x, y, c="b", alpha=0.7, edgecolor="k")

# Plot of the true curve
func_plot(poly, num=100, c="k", label="True Curve")

# Plot the regression curve
model.fit_plot(lw=3, c="r", label="Prediction")

plt.legend(loc="best", frameon=True, shadow=True)
plt.title(f"{model.poly_str(precision=1)}")
plt.show()
plt.close()

# %% [markdown]
# ## Septic Model

# %%
# %time
model = PolynomialSmoother(deg=7).fit(x, y)
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs

# %%
plt.figure()

# Scatter plot of the observations
plt.scatter(x, y, c="b", alpha=0.7, edgecolor="k")

# Plot of the true curve
func_plot(poly, num=100, c="k", label="True Curve")

# Plot the regression curve
model.fit_plot(lw=3, c="r", label="Prediction")

plt.legend(loc="best", frameon=True, shadow=True)
plt.title(f"{model.poly_str(precision=1)}")
plt.show()
plt.close()
